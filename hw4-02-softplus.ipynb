# %%
import numpy as np
import urllib.request

from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.optimizers import Adam, SGD

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/pima-indians-diabetes/pima-indians-diabetes.data"
raw_data = urllib.request.urlopen(url)
dataset = np.loadtxt(raw_data, delimiter=",")
print(dataset.shape)

X = dataset[:,0:8]
Y = dataset[:,8]
# Out:
# (768, 9)

# %%
model = Sequential()
model.add(Dense(12, input_dim=8, activation='softplus', init='uniform'))
model.add(Dense(8 , activation='softplus', init='uniform'))
model.add(Dense(8 , activation='softplus', init='uniform'))
model.add(Dense(1 , activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer="Adam", metrics=['accuracy'])

# %%
model.fit(X, Y, nb_epoch=1000, batch_size=10)
# Out:
# Epoch 1/1000
# 768/768 [==============================] - 0s - loss: 0.6398 - acc: 0.6549
# Epoch 2/1000
# 768/768 [==============================] - 0s - loss: 0.6165 - acc: 0.6706
# Epoch 3/1000
#  - ETA: 0s - loss: 0.6143 - acc: 0.6805
# Epoch 4/1000
# 768/768 [==============================] - 0s - loss: 0.5922 - acc: 0.7018
# Epoch 5/1000
# 768/768 [==============================] - 0s - loss: 0.5710 - acc: 0.7109
# Epoch 6/1000
# 768/768 [==============================] - 0s - loss: 0.5556 - acc: 0.7435
# Epoch 7/1000
# 768/768 [==============================] - 0s - loss: 0.5509 - acc: 0.7292
# Epoch 8/1000
# 768/768 [==============================] - 0s - loss: 0.5450 - acc: 0.7253
# Epoch 9/1000
#  - ETA: 0s - loss: 0.5261 - acc: 0.7660
# Epoch 10/1000
# 768/768 [==============================] - 0s - loss: 0.5283 - acc: 0.7422
# Epoch 11/1000
# 768/768 [==============================] - 0s - loss: 0.5202 - acc: 0.7383
# Epoch 12/1000
# ...

# %%
score = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fa3b6c027150> in <module>()
# ----> 1 score = model.evaluate(X, Y)
#       2 print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
#
# NameError: name 'model' is not defined

# %%
# calculate predictions
predictions = model.predict(X)
# round predictions
rounded = [round(x[0]) for x in predictions]
print(rounded)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-a315481aed94> in <module>()
#       1 # calculate predictions
# ----> 2 predictions = model.predict(X)
#       3 # round predictions
#       4 rounded = [round(x[0]) for x in predictions]
#       5 print(rounded)
#
# NameError: name 'model' is not defined
